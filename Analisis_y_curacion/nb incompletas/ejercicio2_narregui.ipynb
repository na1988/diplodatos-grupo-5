# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import sklearn as skl 
import sympy
import scipy
import seaborn as sns

# %%
pafro = pd.read_json('../AnalisisYCuracion-master/input/pasos.json')
pafro = pafro.apply(lambda x: x.astype(str).str.lower())
pafro['province'] = pafro['province'].str.replace('aeropuerto internacional piloto civil norberto fernandez',
                                                  'santa cruz').replace('córdoba','cordoba')

# %%
pafro = pafro.sort_values('province')

# %%
#pafro['province'].values

# %%
prov = pafro.groupby('province').count().drop(['name'], axis=1)

# %%
prov.plot.bar(figsize=(10,5))
